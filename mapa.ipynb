# %%
import folium # pip install folium
from folium import plugins
import ipywidgets
import geocoder # pip install geocoder
import geopy # pip install geopy
import numpy as np
import pandas as pd
from vega_datasets import data as vds # pip install vega_datasets

# %%
worst_countries = ['Colombia','Costa Rica','South Africa','Mexico','Chile','Korea','Greece','Russia']
best_countries = ['Sweden','Denmark','Netherlands','Norway','Germany','Austria','United Kingdom','Luxembourg']

# %%
countries1=['Colombia','Costa Rica','South Africa','Mexico','Chile','Korea','Greece','Russia']
coordinates1 = [
    (4.5709,-74.2973), #Colombia
    (9.7489, -83.7534), #Costa Rica
    (-30.5595,22.9375), #South Africa
    (23.6345,-102.5528), #Mexico
    (-35.6751,-71.5430), #Chile
    (35.9078,127.7669), #Korea
    (39.0742,21.8243), #Greece
    (61.5240,105.3188) #Rusia
]
country_coordinates1 = dict(zip(countries1, coordinates1))

# %%
countries2 = ['Sweden','Denmark','Netherlands','Norway','Germany','Austria','United Kingdom','Luxembourg']

coordinates2 = [

    (60.1282,18.6435), #Sweden
    (56.2639,9.5018), #Denmark
    (52.1326,5.2913), #Netherlands
    (60.4720,8.4689), #Norway
    (51.1657,10.4515), #Germany
    (47.5162,14.5501), #Austria
    ( 55.3781,-3.4360), #United Kingdom
    (49.8153,6.1296) #Luxembourg
]
country_coordinates2 = dict(zip(countries2, coordinates2))

# %%
countries1 = ['Norway', 'Sweden', 'France', 'Austria', 'Finland', 'Germany', 'Netherlands', 'Denmark', 'Luxembourg', 'Iceland']
coordinates1 = [
    (60.4720, 8.4689),  # Norway
    (60.1282, 18.6435),  # Sweden
    (46.6034, 1.8883),  # France
    (47.5162, 14.5501),  # Austria
    (61.9241, 25.7482),  # Finland
    (51.1657, 10.4515),  # Germany
    (52.1326, 5.2913),  # Netherlands
    (56.2639, 9.5018),  # Denmark
    (49.8153, 6.1296),  # Luxembourg
    (64.9631, -19.0208)  # Iceland
]

country_coordinates1 = dict(zip(countries1, coordinates1))

# %%
countries2 = ['Colombia', 'Chile', 'Mexico', 'Greece', 'Costa Rica']
coordinates2 = [
    (4.5709, -74.2973),  # Colombia
    (-33.4489, -70.6693),  # Chile
    (23.6345, -102.5528),  # Mexico
    (37.9838, 23.7275),  # Greece
    (9.7489, -83.7534)  # Costa Rica
]

country_coordinates2 = dict(zip(countries2, coordinates2))

# %%
map_countries = folium.Map(location=[29.55123418250765, -40.59240676873881], zoom_start=2)
#icono1=folium.Icon(icon_color='red')

for i in country_coordinates1.items():
    folium.Marker(location=i[1], tooltip=i[0],icon=folium.Icon(color='red',icon=i[0])).add_to(map_countries)

for x in country_coordinates2.items():
    folium.Marker(location=x[1], tooltip=x[0]).add_to(map_countries)
    #glyphicon

 
map_countries
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
